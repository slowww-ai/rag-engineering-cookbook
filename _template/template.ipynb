# %% [markdown]
# # <Package Name>
#
# > One-line description of what this package does and where it fits in a RAG pipeline.
#
# - Upstream: <link to package repo or docs>
# - Section in awesome list: <link to relevant section in awesome-rag-engineering>
# - Tested with: `<package>==<version>`, Python <x.y>

# %% [markdown]
# ## 1. Setup
#
# Install dependencies. Pin the version you tested with.

# %%
# %pip install <package>==<version>

# %% [markdown]
# ## 2. Hello World
#
# The smallest working example. Should run end-to-end in under a minute on a laptop.

# %%
# minimal example

# %% [markdown]
# ## 3. Realistic Task
#
# A production-shaped use case on real data. Show inputs, outputs, and how you'd integrate this into a RAG pipeline.

# %%
# realistic example

# %% [markdown]
# ## 4. Gotchas
#
# - Known issues, version pitfalls, performance notes.
# - Anything that surprised you.
# - Cost or latency considerations at production scale.

# %% [markdown]
# ## 5. References
#
# - Upstream docs:
# - Paper (if any):
# - Related notebooks in this cookbook:
